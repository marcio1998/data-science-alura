# %%
import pandas as pd

# %%
s = pd.Series(list('aaasssddddccvbbggtttttt'))
s
# Out:
# 0     a
# 1     a
# 2     a
# 3     s
# 4     s
# 5     s
# 6     d
# 7     d
# 8     d
# 9     d
# 10    c
# 11    c
# 12    v
# 13    b
# 14    b
# 15    g
# 16    g
# 17    t
# 18    t
# 19    t
# 20    t
# 21    t
# 22    t
# dtype: object

# %%
s.unique()
# Out:
# array(['a', 's', 'd', 'c', 'v', 'b', 'g', 't'], dtype=object)

# %%
s.value_counts()
# Out:
# t    6
# d    4
# s    3
# a    3
# c    2
# b    2
# g    2
# v    1
# dtype: int64

# %%
dados = pd.read_csv('aluguel.csv', sep = ";")

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  ...  Condominio    IPTU
# 0                Quitinete       Copacabana  ...       500.0    60.0
# 1                     Casa  Jardim Botânico  ...         NaN     NaN
# 2  Conjunto Comercial/Sala  Barra da Tijuca  ...      4020.0  1111.0
# 3              Apartamento           Centro  ...       390.0    20.0
# 4              Apartamento     Higienópolis  ...       230.0     NaN
# 5              Apartamento     Vista Alegre  ...         NaN     NaN
# 6              Apartamento         Cachambi  ...       301.0    17.0
# 7       Casa de Condomínio  Barra da Tijuca  ...         NaN     NaN
# 8       Casa de Condomínio            Ramos  ...         NaN     NaN
# 9  Conjunto Comercial/Sala           Centro  ...     19193.0  3030.0
#
# [10 rows x 9 columns]

# %%
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel'], dtype=object)

# %%
dados.Tipo.value_counts()
# Out:
# Apartamento                    12487
# Conjunto Comercial/Sala         4406
# Loja/Salão                       916
# Casa de Condomínio               641
# Casa                             598
# Quitinete                        519
# Galpão/Depósito/Armazém          407
# Flat                             301
# Prédio Inteiro                   192
# Casa Comercial                   177
# Loja Shopping/ Ct Comercial      159
# Casa de Vila                     155
# Terreno Padrão                    55
# Box/Garagem                       53
# Loft                              34
# Sítio                              5
# Studio                             3
# Loteamento/Condomínio              2
# Hotel                              1
# Pousada/Chalé                      1
# Chácara                            1
# Name: Tipo, dtype: int64
